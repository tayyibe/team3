# %%
import numpy as np
from aicsimageio import AICSImage
from cellpose import models
import matplotlib.pyplot as plt
import skimage
print("All imports OK")
print("Python:", )
print("numpy:", np.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 from aicsimageio import AICSImage
#       3 from cellpose import models
#       4 import matplotlib.pyplot as plt
#       5 import skimage
#
# ModuleNotFoundError: No module named 'aicsimageio'

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /Users/tayyibekansoy/Desktop/Hackathon/.venv/bin/python
# 3.14.4 (v3.14.4:23116f998f6, Apr  7 2026, 09:45:22) [Clang 17.0.0 (clang-1700.6.4.2)]
